# %%
from groq_api import get_groq_summary

from openai_api import get_image_summary
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from groq_api import get_groq_summary
#       3 from openai_api import get_image_summary
#
# File ~/Sync/Code/3PeasInAPod/backend/utils/groq_api.py:2
#       1 from groq import Groq
# ----> 2 from utils.configs import get_config
#       4 client = Groq(
#       5     api_key=get_config()["GROQ_API_KEY"],
#       6 )
#       9 USER_PROMPT = """
#      10 Prompt:
# ...

# %%
import base64

with open("../trash.jpeg", "rb") as image_file:
    encoded_string = base64.b64encode(image_file.read())

# %%
encoded_string = encoded_string.decode("utf-8")

# %%
encoded_string
# Out:
# '...'

# %%
# call async function

async def main():
    image_summary = await get_image_summary(str(encoded_string), aggressiveness=10)
    print(image_summary)

# %%
# call main
await main()
# Out:
# It appears the person is about to dispose of some plastic wrap, but it’s unclear if they are throwing it in the trash or recycling bin.
#
# If they’re planning to toss it on the ground, that's absolutely unacceptable! Littering is harmful to the environment. Please use a trash can or recycling bin to dispose of plastic properly. Keep our spaces clean!
# It appears the person is about to dispose of some plastic wrap, but it’s unclear if they are throwing it in the trash or recycling bin.
#
# If they’re planning to toss it on the ground, that's absolutely unacceptable! Littering is harmful to the environment. Please use a trash can or recycling bin to dispose of plastic properly. Keep our spaces clean!
